# %%
from pyspark.sql.functions import col, to_timestamp

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder \
        .appName("Day3 Telematics Project") \
        .getOrCreate()

# %%
spark.conf.set("spark.sql.adaptive.enabled","false")

# %%
df_tele = spark.read.csv("/opt/spark-data/telematics.csv",header=True,inferSchema=True)
df_vehicle = spark.read.csv("/opt/spark-data/vehicles.csv",header=True,inferSchema=True)

# %%
df_tele.printSchema()
df_vehicle.show()
df_tele.show(5)
# Out:
# root
#  |-- timestamp: timestamp (nullable = true)
#  |-- vehicle_id: string (nullable = true)
#  |-- speed: integer (nullable = true)
#  |-- engine_temp: integer (nullable = true)
#  |-- fuel_level: integer (nullable = true)
#  |-- lat: double (nullable = true)
#  |-- lon: double (nullable = true)
#
# +----------+-----+-----+----+
# |vehicle_id|model|plant|year|
# +----------+-----+-----+----+
# |        V1|Sedan|    A|2022|
# |        V2|  SUV|    B|2023|
# |        V3|Truck|    A|2021|
# |        V4|Sedan|    C|2020|
# |        V5|  SUV|    B|2022|
# +----------+-----+-----+----+
#
# +-------------------+----------+-----+-----------+----------+--------+--------+
# |          timestamp|vehicle_id|speed|engine_temp|fuel_level|     lat|     lon|
# +-------------------+----------+-----+-----------+----------+--------+--------+
# |2024-03-01 00:00:00|        V1|   41|         84|        50|13.72701|77.92426|
# |2024-03-01 00:00:00|        V2|   17|        105|        95|13.86915|77.90112|
# |2024-03-01 00:00:00|        V3|   79|         94|        79|13.06656|78.44125|
# |2024-03-01 00:00:00|        V4|  100|        117|        44|13.57825|78.28303|
# |2024-03-01 00:00:00|        V5|   80|         70|        83|13.74648|77.68761|
# +-------------------+----------+-----+-----------+----------+--------+--------+
# only showing top 5 rows

# %%
from pyspark.sql.functions import lit

df_big = df_tele
df_big = df_big.withColumn("dup_id",lit(0))
for i in range(20):   # increase multiplier gradually
    df_big = df_big.union(df_tele.withColumn("dup_id", lit(i)))

df_big.count()
# Out:
# 907200

# %%
df_tele = df_big

# %%
df_tele = df_tele.withColumn(
    "timestamp",
    to_timestamp(col("timestamp"))
)

# %%
from pyspark.sql.functions import when

df_tele = df_tele.withColumn(
    "speed_category",
    when(col("speed") < 40, "low")
    .when(col("speed") < 80, "medium")
    .otherwise("high")
)

df_tele = df_tele.withColumn(
    "engine_stress",
    col("engine_temp") * col("speed")
)

# %%
df_agg = df_tele.groupBy("vehicle_id").agg(
    {"speed": "avg", "fuel_level": "avg"}
)

df_agg.show()
# Out:
# +----------+------------------+------------------+
# |vehicle_id|   avg(fuel_level)|        avg(speed)|
# +----------+------------------+------------------+
# |        V3| 55.39780092592593|  60.1712962962963|
# |        V4| 55.29907407407408| 59.89189814814815|
# |        V5| 54.89247685185185| 59.64039351851852|
# |        V2|55.083333333333336|60.079166666666666|
# |        V1|54.793055555555554| 59.90127314814815|
# +----------+------------------+------------------+

# %%
df_joined = df_tele.join(df_vehicle, on="vehicle_id", how="inner")
df_joined.explain()
# Out:
# == Physical Plan ==
# *(23) Project [vehicle_id#18, timestamp#637, speed#19, engine_temp#20, fuel_level#21, lat#22, lon#23, dup_id#115, speed_category#646, engine_stress#656, model#49, plant#50, year#51]
# +- *(23) BroadcastHashJoin [vehicle_id#18], [vehicle_id#48], Inner, BuildRight, false
#    :- Union
#    :  :- *(1) Project [timestamp#17 AS timestamp#637, vehicle_id#18, speed#19, engine_temp#20, fuel_level#21, lat#22, lon#23, 0 AS dup_id#115, CASE WHEN (speed#19 < 40) THEN low WHEN (speed#19 < 80) THEN medium ELSE high END AS speed_category#646, (engine_temp#20 * speed#19) AS engine_stress#656]
#    :  :  +- *(1) Filter isnotnull(vehicle_id#18)
#    :  :     +- FileScan csv [timestamp#17,vehicle_id#18,speed#19,engine_temp#20,fuel_level#21,lat#22,lon#23] Batched: false, DataFilters: [isnotnull(vehicle_id#18)], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/opt/spark-data/telematics.csv], PartitionFilters: [], PushedFilters: [IsNotNull(vehicle_id)], ReadSchema: struct<timestamp:timestamp,vehicle_id:string,speed:int,engine_temp:int,fuel_level:int,lat:double,...
#    :  :- *(2) Project [timestamp#133, vehicle_id#134, speed#135, engine_temp#136, fuel_level#137, lat#138, lon#139, 0 AS dup_id#124, CASE WHEN (speed#135 < 40) THEN low WHEN (speed#135 < 80) THEN medium ELSE high END AS speed_category#825, (engine_temp#136 * speed#135) AS engine_stress#826]
#    :  :  +- *(2) Filter isnotnull(vehicle_id#134)
#    :  :     +- FileScan csv [timestamp#133,vehicle_id#134,speed#135,engine_temp#136,fuel_level#137,lat#138,lon#139] Batched: false, DataFilters: [isnotnull(vehicle_id#134)], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/opt/spark-data/telematics.csv], PartitionFilters: [], PushedFilters: [IsNotNull(vehicle_id)], ReadSchema: struct<timestamp:timestamp,vehicle_id:string,speed:int,engine_temp:int,fuel_level:int,lat:double,...
#    :  :- *(3) Project [timestamp#158, vehicle_id#159, speed#160, engine_temp#161, fuel_level#162, lat#163, lon#164, 1 AS dup_id#149, CASE WHEN (speed#160 < 40) THEN low WHEN (speed#160 < 80) THEN medium ELSE high END AS speed_category#827, (engine_temp#161 * speed#160) AS engine_stress#828]
#    :  :  +- *(3) Filter isnotnull(vehicle_id#159)
#    :  :     +- FileScan csv [timestamp#158,vehicle_id#159,speed#160,engine_temp#161,fuel_level#162,lat#163,lon#164] Batched: false, DataFilters: [isnotnull(vehicle_id#159)], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/opt/spark-data/telematics.csv], PartitionFilters: [], PushedFilters: [IsNotNull(vehicle_id)], ReadSchema: struct<timestamp:timestamp,vehicle_id:string,speed:int,engine_temp:int,fuel_level:int,lat:double,...
#    :  :- *(4) Project [timestamp#183, vehicle_id#184, speed#185, engine_temp#186, fuel_level#187, lat#188, lon#189, 2 AS dup_id#174, CASE WHEN (speed#185 < 40) THEN low WHEN (speed#185 < 80) THEN medium ELSE high END AS speed_category#829, (engine_temp#186 * speed#185) AS engine_stress#830]
#    :  :  +- *(4) Filter isnotnull(vehicle_id#184)
#    :  :     +- FileScan csv [timestamp#183,vehicle_id#184,speed#185,engine_temp#186,fuel_level#187,lat#188,lon#189] Batched: false, DataFilters: [isnotnull(vehicle_id#184)], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/opt/spark-data/telematics.csv], PartitionFilters: [], PushedFilters: [IsNotNull(vehicle_id)], ReadSchema: struct<timestamp:timestamp,vehicle_id:string,speed:int,engine_temp:int,fuel_level:int,lat:double,...
#    :  :- *(5) Project [timestamp#208, vehicle_id#209, speed#210, engine_temp#211, fuel_level#212, lat#213, lon#214, 3 AS dup_id#199, CASE WHEN (speed#210 < 40) THEN low WHEN (speed#210 < 80) THEN medium ELSE high END AS speed_category#831, (engine_temp#211 * speed#210) AS engine_stress#832]
#    :  :  +- *(5) Filter isnotnull(vehicle_id#209)
#    :  :     +- FileScan csv [timestamp#208,vehicle_id#209,speed#210,engine_temp#211,fuel_level#212,lat#213,lon#214] Batched: false, DataFilters: [isnotnull(vehicle_id#209)], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/opt/spark-data/telematics.csv], PartitionFilters: [], PushedFilters: [IsNotNull(vehicle_id)], ReadSchema: struct<timestamp:timestamp,vehicle_id:string,speed:int,engine_temp:int,fuel_level:int,lat:double,...
#    :  :- *(6) Project [timestamp#233, vehicle_id#234, speed#235, engine_temp#236, fuel_level#237, lat#238, lon#239, 4 AS dup_id#224, CASE WHEN (speed#235 < 40) THEN low WHEN (speed#235 < 80) THEN medium ELSE high END AS speed_category#833, (engine_temp#236 * speed#235) AS engine_stress#834]
#    :  :  +- *(6) Filter isnotnull(vehicle_id#234)
#    :  :     +- FileScan csv [timestamp#233,vehicle_id#234,speed#235,engine_temp#236,fuel_level#237,lat#238,lon#239] Batched: false, DataFilters: [isnotnull(vehicle_id#234)], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/opt/spark-data/telematics.csv], PartitionFilters: [], PushedFilters: [IsNotNull(vehicle_id)], ReadSchema: struct<timestamp:timestamp,vehicle_id:string,speed:int,engine_temp:int,fuel_level:int,lat:double,...
#    :  :- *(7) Project [timestamp#258, vehicle_id#259, speed#260, engine_temp#261, fuel_level#262, lat#263, lon#264, 5 AS dup_id#249, CASE WHEN (speed#260 < 40) THEN low WHEN (speed#260 < 80) THEN medium ELSE high END AS speed_category#835, (engine_temp#261 * speed#260) AS engine_stress#836]
#    :  :  +- *(7) Filter isnotnull(vehicle_id#259)
#    :  :     +- FileScan csv [timestamp#258,vehicle_id#259,speed#260,engine_temp#261,fuel_level#262,lat#263,lon#264] Batched: false, DataFilters: [isnotnull(vehicle_id#259)], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/opt/spark-data/telematics.csv], PartitionFilters: [], PushedFilters: [IsNotNull(vehicle_id)], ReadSchema: struct<timestamp:timestamp,vehicle_id:string,speed:int,engine_temp:int,fuel_level:int,lat:double,...
#    :  :- *(8) Project [timestamp#283, vehicle_id#284, speed#285, engine_temp#286, fuel_level#287, lat#288, lon#289, 6 AS dup_id#274, CASE WHEN (speed#285 < 40) THEN low WHEN (speed#285 < 80) THEN medium ELSE high END AS speed_category#837, (engine_temp#286 * speed#285) AS engine_stress#838]
#    :  :  +- *(8) Filter isnotnull(vehicle_id#284)
#    :  :     +- FileScan csv [timestamp#283,vehicle_id#284,speed#285,engine_temp#286,fuel_level#287,lat#288,lon#289] Batched: false, DataFilters: [isnotnull(vehicle_id#284)], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/opt/spark-data/telematics.csv], PartitionFilters: [], PushedFilters: [IsNotNull(vehicle_id)], ReadSchema: struct<timestamp:timestamp,vehicle_id:string,speed:int,engine_temp:int,fuel_level:int,lat:double,...
#    :  :- *(9) Project [timestamp#308, vehicle_id#309, speed#310, engine_temp#311, fuel_level#312, lat#313, lon#314, 7 AS dup_id#299, CASE WHEN (speed#310 < 40) THEN low WHEN (speed#310 < 80) THEN medium ELSE high END AS speed_category#839, (engine_temp#311 * speed#310) AS engine_stress#840]
#    :  :  +- *(9) Filter isnotnull(vehicle_id#309)
#    :  :     +- FileScan csv [timestamp#308,vehicle_id#309,speed#310,engine_temp#311,fuel_level#312,lat#313,lon#314] Batched: false, DataFilters: [isnotnull(vehicle_id#309)], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/opt/spark-data/telematics.csv], PartitionFilters: [], PushedFilters: [IsNotNull(vehicle_id)], ReadSchema: struct<timestamp:timestamp,vehicle_id:string,speed:int,engine_temp:int,fuel_level:int,lat:double,...
#    :  :- *(10) Project [timestamp#333, vehicle_id#334, speed#335, engine_temp#336, fuel_level#337, lat#338, lon#339, 8 AS dup_id#324, CASE WHEN (speed#335 < 40) THEN low WHEN (speed#335 < 80) THEN medium ELSE high END AS speed_category#841, (engine_temp#336 * speed#335) AS engine_stress#842]
#    :  :  +- *(10) Filter isnotnull(vehicle_id#334)
#    :  :     +- FileScan csv [timestamp#333,vehicle_id#334,speed#335,engine_temp#336,fuel_level#337,lat#338,lon#339] Batched: false, DataFilters: [isnotnull(vehicle_id#334)], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/opt/spark-data/telematics.csv], PartitionFilters: [], PushedFilters: [IsNotNull(vehicle_id)], ReadSchema: struct<timestamp:timestamp,vehicle_id:string,speed:int,engine_temp:int,fuel_level:int,lat:double,...
#    :  :- *(11) Project [timestamp#358, vehicle_id#359, speed#360, engine_temp#361, fuel_level#362, lat#363, lon#364, 9 AS dup_id#349, CASE WHEN (speed#360 < 40) THEN low WHEN (speed#360 < 80) THEN medium ELSE high END AS speed_category#843, (engine_temp#361 * speed#360) AS engine_stress#844]
#    :  :  +- *(11) Filter isnotnull(vehicle_id#359)
#    :  :     +- FileScan csv [timestamp#358,vehicle_id#359,speed#360,engine_temp#361,fuel_level#362,lat#363,lon#364] Batched: false, DataFilters: [isnotnull(vehicle_id#359)], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/opt/spark-data/telematics.csv], PartitionFilters: [], PushedFilters: [IsNotNull(vehicle_id)], ReadSchema: struct<timestamp:timestamp,vehicle_id:string,speed:int,engine_temp:int,fuel_level:int,lat:double,...
#    :  :- *(12) Project [timestamp#383, vehicle_id#384, speed#385, engine_temp#386, fuel_level#387, lat#388, lon#389, 10 AS dup_id#374, CASE WHEN (speed#385 < 40) THEN low WHEN (speed#385 < 80) THEN medium ELSE high END AS speed_category#845, (engine_temp#386 * speed#385) AS engine_stress#846]
#    :  :  +- *(12) Filter isnotnull(vehicle_id#384)
#    :  :     +- FileScan csv [timestamp#383,vehicle_id#384,speed#385,engine_temp#386,fuel_level#387,lat#388,lon#389] Batched: false, DataFilters: [isnotnull(vehicle_id#384)], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/opt/spark-data/telematics.csv], PartitionFilters: [], PushedFilters: [IsNotNull(vehicle_id)], ReadSchema: struct<timestamp:timestamp,vehicle_id:string,speed:int,engine_temp:int,fuel_level:int,lat:double,...
#    :  :- *(13) Project [timestamp#408, vehicle_id#409, speed#410, engine_temp#411, fuel_level#412, lat#413, lon#414, 11 AS dup_id#399, CASE WHEN (speed#410 < 40) THEN low WHEN (speed#410 < 80) THEN medium ELSE high END AS speed_category#847, (engine_temp#411 * speed#410) AS engine_stress#848]
#    :  :  +- *(13) Filter isnotnull(vehicle_id#409)
#    :  :     +- FileScan csv [timestamp#408,vehicle_id#409,speed#410,engine_temp#411,fuel_level#412,lat#413,lon#414] Batched: false, DataFilters: [isnotnull(vehicle_id#409)], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/opt/spark-data/telematics.csv], PartitionFilters: [], PushedFilters: [IsNotNull(vehicle_id)], ReadSchema: struct<timestamp:timestamp,vehicle_id:string,speed:int,engine_temp:int,fuel_level:int,lat:double,...
#    :  :- *(14) Project [timestamp#433, vehicle_id#434, speed#435, engine_temp#436, fuel_level#437, lat#438, lon#439, 12 AS dup_id#424, CASE WHEN (speed#435 < 40) THEN low WHEN (speed#435 < 80) THEN medium ELSE high END AS speed_category#849, (engine_temp#436 * speed#435) AS engine_stress#850]
#    :  :  +- *(14) Filter isnotnull(vehicle_id#434)
#    :  :     +- FileScan csv [timestamp#433,vehicle_id#434,speed#435,engine_temp#436,fuel_level#437,lat#438,lon#439] Batched: false, DataFilters: [isnotnull(vehicle_id#434)], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/opt/spark-data/telematics.csv], PartitionFilters: [], PushedFilters: [IsNotNull(vehicle_id)], ReadSchema: struct<timestamp:timestamp,vehicle_id:string,speed:int,engine_temp:int,fuel_level:int,lat:double,...
#    :  :- *(15) Project [timestamp#458, vehicle_id#459, speed#460, engine_temp#461, fuel_level#462, lat#463, lon#464, 13 AS dup_id#449, CASE WHEN (speed#460 < 40) THEN low WHEN (speed#460 < 80) THEN medium ELSE high END AS speed_category#851, (engine_temp#461 * speed#460) AS engine_stress#852]
#    :  :  +- *(15) Filter isnotnull(vehicle_id#459)
#    :  :     +- FileScan csv [timestamp#458,vehicle_id#459,speed#460,engine_temp#461,fuel_level#462,lat#463,lon#464] Batched: false, DataFilters: [isnotnull(vehicle_id#459)], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/opt/spark-data/telematics.csv], PartitionFilters: [], PushedFilters: [IsNotNull(vehicle_id)], ReadSchema: struct<timestamp:timestamp,vehicle_id:string,speed:int,engine_temp:int,fuel_level:int,lat:double,...
#    :  :- *(16) Project [timestamp#483, vehicle_id#484, speed#485, engine_temp#486, fuel_level#487, lat#488, lon#489, 14 AS dup_id#474, CASE WHEN (speed#485 < 40) THEN low WHEN (speed#485 < 80) THEN medium ELSE high END AS speed_category#853, (engine_temp#486 * speed#485) AS engine_stress#854]
#    :  :  +- *(16) Filter isnotnull(vehicle_id#484)
#    :  :     +- FileScan csv [timestamp#483,vehicle_id#484,speed#485,engine_temp#486,fuel_level#487,lat#488,lon#489] Batched: false, DataFilters: [isnotnull(vehicle_id#484)], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/opt/spark-data/telematics.csv], PartitionFilters: [], PushedFilters: [IsNotNull(vehicle_id)], ReadSchema: struct<timestamp:timestamp,vehicle_id:string,speed:int,engine_temp:int,fuel_level:int,lat:double,...
#    :  :- *(17) Project [timestamp#508, vehicle_id#509, speed#510, engine_temp#511, fuel_level#512, lat#513, lon#514, 15 AS dup_id#499, CASE WHEN (speed#510 < 40) THEN low WHEN (speed#510 < 80) THEN medium ELSE high END AS speed_category#855, (engine_temp#511 * speed#510) AS engine_stress#856]
#    :  :  +- *(17) Filter isnotnull(vehicle_id#509)
#    :  :     +- FileScan csv [timestamp#508,vehicle_id#509,speed#510,engine_temp#511,fuel_level#512,lat#513,lon#514] Batched: false, DataFilters: [isnotnull(vehicle_id#509)], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/opt/spark-data/telematics.csv], PartitionFilters: [], PushedFilters: [IsNotNull(vehicle_id)], ReadSchema: struct<timestamp:timestamp,vehicle_id:string,speed:int,engine_temp:int,fuel_level:int,lat:double,...
#    :  :- *(18) Project [timestamp#533, vehicle_id#534, speed#535, engine_temp#536, fuel_level#537, lat#538, lon#539, 16 AS dup_id#524, CASE WHEN (speed#535 < 40) THEN low WHEN (speed#535 < 80) THEN medium ELSE high END AS speed_category#857, (engine_temp#536 * speed#535) AS engine_stress#858]
#    :  :  +- *(18) Filter isnotnull(vehicle_id#534)
#    :  :     +- FileScan csv [timestamp#533,vehicle_id#534,speed#535,engine_temp#536,fuel_level#537,lat#538,lon#539] Batched: false, DataFilters: [isnotnull(vehicle_id#534)], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/opt/spark-data/telematics.csv], PartitionFilters: [], PushedFilters: [IsNotNull(vehicle_id)], ReadSchema: struct<timestamp:timestamp,vehicle_id:string,speed:int,engine_temp:int,fuel_level:int,lat:double,...
#    :  :- *(19) Project [timestamp#558, vehicle_id#559, speed#560, engine_temp#561, fuel_level#562, lat#563, lon#564, 17 AS dup_id#549, CASE WHEN (speed#560 < 40) THEN low WHEN (speed#560 < 80) THEN medium ELSE high END AS speed_category#859, (engine_temp#561 * speed#560) AS engine_stress#860]
#    :  :  +- *(19) Filter isnotnull(vehicle_id#559)
#    :  :     +- FileScan csv [timestamp#558,vehicle_id#559,speed#560,engine_temp#561,fuel_level#562,lat#563,lon#564] Batched: false, DataFilters: [isnotnull(vehicle_id#559)], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/opt/spark-data/telematics.csv], PartitionFilters: [], PushedFilters: [IsNotNull(vehicle_id)], ReadSchema: struct<timestamp:timestamp,vehicle_id:string,speed:int,engine_temp:int,fuel_level:int,lat:double,...
#    :  :- *(20) Project [timestamp#583, vehicle_id#584, speed#585, engine_temp#586, fuel_level#587, lat#588, lon#589, 18 AS dup_id#574, CASE WHEN (speed#585 < 40) THEN low WHEN (speed#585 < 80) THEN medium ELSE high END AS speed_category#861, (engine_temp#586 * speed#585) AS engine_stress#862]
#    :  :  +- *(20) Filter isnotnull(vehicle_id#584)
#    :  :     +- FileScan csv [timestamp#583,vehicle_id#584,speed#585,engine_temp#586,fuel_level#587,lat#588,lon#589] Batched: false, DataFilters: [isnotnull(vehicle_id#584)], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/opt/spark-data/telematics.csv], PartitionFilters: [], PushedFilters: [IsNotNull(vehicle_id)], ReadSchema: struct<timestamp:timestamp,vehicle_id:string,speed:int,engine_temp:int,fuel_level:int,lat:double,...
#    :  +- *(21) Project [timestamp#608, vehicle_id#609, speed#610, engine_temp#611, fuel_level#612, lat#613, lon#614, 19 AS dup_id#599, CASE WHEN (speed#610 < 40) THEN low WHEN (speed#610 < 80) THEN medium ELSE high END AS speed_category#863, (engine_temp#611 * speed#610) AS engine_stress#864]
#    :     +- *(21) Filter isnotnull(vehicle_id#609)
#    :        +- FileScan csv [timestamp#608,vehicle_id#609,speed#610,engine_temp#611,fuel_level#612,lat#613,lon#614] Batched: false, DataFilters: [isnotnull(vehicle_id#609)], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/opt/spark-data/telematics.csv], PartitionFilters: [], PushedFilters: [IsNotNull(vehicle_id)], ReadSchema: struct<timestamp:timestamp,vehicle_id:string,speed:int,engine_temp:int,fuel_level:int,lat:double,...
#    +- BroadcastExchange HashedRelationBroadcastMode(List(input[0, string, false]),false), [plan_id=608]
#       +- *(22) Filter isnotnull(vehicle_id#48)
#          +- FileScan csv [vehicle_id#48,model#49,plant#50,year#51] Batched: false, DataFilters: [isnotnull(vehicle_id#48)], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/opt/spark-data/vehicles.csv], PartitionFilters: [], PushedFilters: [IsNotNull(vehicle_id)], ReadSchema: struct<vehicle_id:string,model:string,plant:string,year:int>

# %%
from pyspark.sql.functions import broadcast

df_joined_broadcast = df_tele.join(
    broadcast(df_vehicle),
    on="vehicle_id",
    how="inner"
)

df_joined_broadcast.explain()
# Out:
# == Physical Plan ==
# *(23) Project [vehicle_id#18, timestamp#637, speed#19, engine_temp#20, fuel_level#21, lat#22, lon#23, dup_id#115, speed_category#646, engine_stress#656, model#49, plant#50, year#51]
# +- *(23) BroadcastHashJoin [vehicle_id#18], [vehicle_id#48], Inner, BuildRight, false
#    :- Union
#    :  :- *(1) Project [timestamp#17 AS timestamp#637, vehicle_id#18, speed#19, engine_temp#20, fuel_level#21, lat#22, lon#23, 0 AS dup_id#115, CASE WHEN (speed#19 < 40) THEN low WHEN (speed#19 < 80) THEN medium ELSE high END AS speed_category#646, (engine_temp#20 * speed#19) AS engine_stress#656]
#    :  :  +- *(1) Filter isnotnull(vehicle_id#18)
#    :  :     +- FileScan csv [timestamp#17,vehicle_id#18,speed#19,engine_temp#20,fuel_level#21,lat#22,lon#23] Batched: false, DataFilters: [isnotnull(vehicle_id#18)], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/opt/spark-data/telematics.csv], PartitionFilters: [], PushedFilters: [IsNotNull(vehicle_id)], ReadSchema: struct<timestamp:timestamp,vehicle_id:string,speed:int,engine_temp:int,fuel_level:int,lat:double,...
#    :  :- *(2) Project [timestamp#133, vehicle_id#134, speed#135, engine_temp#136, fuel_level#137, lat#138, lon#139, 0 AS dup_id#124, CASE WHEN (speed#135 < 40) THEN low WHEN (speed#135 < 80) THEN medium ELSE high END AS speed_category#898, (engine_temp#136 * speed#135) AS engine_stress#899]
#    :  :  +- *(2) Filter isnotnull(vehicle_id#134)
#    :  :     +- FileScan csv [timestamp#133,vehicle_id#134,speed#135,engine_temp#136,fuel_level#137,lat#138,lon#139] Batched: false, DataFilters: [isnotnull(vehicle_id#134)], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/opt/spark-data/telematics.csv], PartitionFilters: [], PushedFilters: [IsNotNull(vehicle_id)], ReadSchema: struct<timestamp:timestamp,vehicle_id:string,speed:int,engine_temp:int,fuel_level:int,lat:double,...
#    :  :- *(3) Project [timestamp#158, vehicle_id#159, speed#160, engine_temp#161, fuel_level#162, lat#163, lon#164, 1 AS dup_id#149, CASE WHEN (speed#160 < 40) THEN low WHEN (speed#160 < 80) THEN medium ELSE high END AS speed_category#900, (engine_temp#161 * speed#160) AS engine_stress#901]
#    :  :  +- *(3) Filter isnotnull(vehicle_id#159)
#    :  :     +- FileScan csv [timestamp#158,vehicle_id#159,speed#160,engine_temp#161,fuel_level#162,lat#163,lon#164] Batched: false, DataFilters: [isnotnull(vehicle_id#159)], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/opt/spark-data/telematics.csv], PartitionFilters: [], PushedFilters: [IsNotNull(vehicle_id)], ReadSchema: struct<timestamp:timestamp,vehicle_id:string,speed:int,engine_temp:int,fuel_level:int,lat:double,...
#    :  :- *(4) Project [timestamp#183, vehicle_id#184, speed#185, engine_temp#186, fuel_level#187, lat#188, lon#189, 2 AS dup_id#174, CASE WHEN (speed#185 < 40) THEN low WHEN (speed#185 < 80) THEN medium ELSE high END AS speed_category#902, (engine_temp#186 * speed#185) AS engine_stress#903]
#    :  :  +- *(4) Filter isnotnull(vehicle_id#184)
#    :  :     +- FileScan csv [timestamp#183,vehicle_id#184,speed#185,engine_temp#186,fuel_level#187,lat#188,lon#189] Batched: false, DataFilters: [isnotnull(vehicle_id#184)], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/opt/spark-data/telematics.csv], PartitionFilters: [], PushedFilters: [IsNotNull(vehicle_id)], ReadSchema: struct<timestamp:timestamp,vehicle_id:string,speed:int,engine_temp:int,fuel_level:int,lat:double,...
#    :  :- *(5) Project [timestamp#208, vehicle_id#209, speed#210, engine_temp#211, fuel_level#212, lat#213, lon#214, 3 AS dup_id#199, CASE WHEN (speed#210 < 40) THEN low WHEN (speed#210 < 80) THEN medium ELSE high END AS speed_category#904, (engine_temp#211 * speed#210) AS engine_stress#905]
#    :  :  +- *(5) Filter isnotnull(vehicle_id#209)
#    :  :     +- FileScan csv [timestamp#208,vehicle_id#209,speed#210,engine_temp#211,fuel_level#212,lat#213,lon#214] Batched: false, DataFilters: [isnotnull(vehicle_id#209)], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/opt/spark-data/telematics.csv], PartitionFilters: [], PushedFilters: [IsNotNull(vehicle_id)], ReadSchema: struct<timestamp:timestamp,vehicle_id:string,speed:int,engine_temp:int,fuel_level:int,lat:double,...
#    :  :- *(6) Project [timestamp#233, vehicle_id#234, speed#235, engine_temp#236, fuel_level#237, lat#238, lon#239, 4 AS dup_id#224, CASE WHEN (speed#235 < 40) THEN low WHEN (speed#235 < 80) THEN medium ELSE high END AS speed_category#906, (engine_temp#236 * speed#235) AS engine_stress#907]
#    :  :  +- *(6) Filter isnotnull(vehicle_id#234)
#    :  :     +- FileScan csv [timestamp#233,vehicle_id#234,speed#235,engine_temp#236,fuel_level#237,lat#238,lon#239] Batched: false, DataFilters: [isnotnull(vehicle_id#234)], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/opt/spark-data/telematics.csv], PartitionFilters: [], PushedFilters: [IsNotNull(vehicle_id)], ReadSchema: struct<timestamp:timestamp,vehicle_id:string,speed:int,engine_temp:int,fuel_level:int,lat:double,...
#    :  :- *(7) Project [timestamp#258, vehicle_id#259, speed#260, engine_temp#261, fuel_level#262, lat#263, lon#264, 5 AS dup_id#249, CASE WHEN (speed#260 < 40) THEN low WHEN (speed#260 < 80) THEN medium ELSE high END AS speed_category#908, (engine_temp#261 * speed#260) AS engine_stress#909]
#    :  :  +- *(7) Filter isnotnull(vehicle_id#259)
#    :  :     +- FileScan csv [timestamp#258,vehicle_id#259,speed#260,engine_temp#261,fuel_level#262,lat#263,lon#264] Batched: false, DataFilters: [isnotnull(vehicle_id#259)], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/opt/spark-data/telematics.csv], PartitionFilters: [], PushedFilters: [IsNotNull(vehicle_id)], ReadSchema: struct<timestamp:timestamp,vehicle_id:string,speed:int,engine_temp:int,fuel_level:int,lat:double,...
#    :  :- *(8) Project [timestamp#283, vehicle_id#284, speed#285, engine_temp#286, fuel_level#287, lat#288, lon#289, 6 AS dup_id#274, CASE WHEN (speed#285 < 40) THEN low WHEN (speed#285 < 80) THEN medium ELSE high END AS speed_category#910, (engine_temp#286 * speed#285) AS engine_stress#911]
#    :  :  +- *(8) Filter isnotnull(vehicle_id#284)
#    :  :     +- FileScan csv [timestamp#283,vehicle_id#284,speed#285,engine_temp#286,fuel_level#287,lat#288,lon#289] Batched: false, DataFilters: [isnotnull(vehicle_id#284)], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/opt/spark-data/telematics.csv], PartitionFilters: [], PushedFilters: [IsNotNull(vehicle_id)], ReadSchema: struct<timestamp:timestamp,vehicle_id:string,speed:int,engine_temp:int,fuel_level:int,lat:double,...
#    :  :- *(9) Project [timestamp#308, vehicle_id#309, speed#310, engine_temp#311, fuel_level#312, lat#313, lon#314, 7 AS dup_id#299, CASE WHEN (speed#310 < 40) THEN low WHEN (speed#310 < 80) THEN medium ELSE high END AS speed_category#912, (engine_temp#311 * speed#310) AS engine_stress#913]
#    :  :  +- *(9) Filter isnotnull(vehicle_id#309)
#    :  :     +- FileScan csv [timestamp#308,vehicle_id#309,speed#310,engine_temp#311,fuel_level#312,lat#313,lon#314] Batched: false, DataFilters: [isnotnull(vehicle_id#309)], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/opt/spark-data/telematics.csv], PartitionFilters: [], PushedFilters: [IsNotNull(vehicle_id)], ReadSchema: struct<timestamp:timestamp,vehicle_id:string,speed:int,engine_temp:int,fuel_level:int,lat:double,...
#    :  :- *(10) Project [timestamp#333, vehicle_id#334, speed#335, engine_temp#336, fuel_level#337, lat#338, lon#339, 8 AS dup_id#324, CASE WHEN (speed#335 < 40) THEN low WHEN (speed#335 < 80) THEN medium ELSE high END AS speed_category#914, (engine_temp#336 * speed#335) AS engine_stress#915]
#    :  :  +- *(10) Filter isnotnull(vehicle_id#334)
#    :  :     +- FileScan csv [timestamp#333,vehicle_id#334,speed#335,engine_temp#336,fuel_level#337,lat#338,lon#339] Batched: false, DataFilters: [isnotnull(vehicle_id#334)], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/opt/spark-data/telematics.csv], PartitionFilters: [], PushedFilters: [IsNotNull(vehicle_id)], ReadSchema: struct<timestamp:timestamp,vehicle_id:string,speed:int,engine_temp:int,fuel_level:int,lat:double,...
#    :  :- *(11) Project [timestamp#358, vehicle_id#359, speed#360, engine_temp#361, fuel_level#362, lat#363, lon#364, 9 AS dup_id#349, CASE WHEN (speed#360 < 40) THEN low WHEN (speed#360 < 80) THEN medium ELSE high END AS speed_category#916, (engine_temp#361 * speed#360) AS engine_stress#917]
#    :  :  +- *(11) Filter isnotnull(vehicle_id#359)
#    :  :     +- FileScan csv [timestamp#358,vehicle_id#359,speed#360,engine_temp#361,fuel_level#362,lat#363,lon#364] Batched: false, DataFilters: [isnotnull(vehicle_id#359)], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/opt/spark-data/telematics.csv], PartitionFilters: [], PushedFilters: [IsNotNull(vehicle_id)], ReadSchema: struct<timestamp:timestamp,vehicle_id:string,speed:int,engine_temp:int,fuel_level:int,lat:double,...
#    :  :- *(12) Project [timestamp#383, vehicle_id#384, speed#385, engine_temp#386, fuel_level#387, lat#388, lon#389, 10 AS dup_id#374, CASE WHEN (speed#385 < 40) THEN low WHEN (speed#385 < 80) THEN medium ELSE high END AS speed_category#918, (engine_temp#386 * speed#385) AS engine_stress#919]
#    :  :  +- *(12) Filter isnotnull(vehicle_id#384)
#    :  :     +- FileScan csv [timestamp#383,vehicle_id#384,speed#385,engine_temp#386,fuel_level#387,lat#388,lon#389] Batched: false, DataFilters: [isnotnull(vehicle_id#384)], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/opt/spark-data/telematics.csv], PartitionFilters: [], PushedFilters: [IsNotNull(vehicle_id)], ReadSchema: struct<timestamp:timestamp,vehicle_id:string,speed:int,engine_temp:int,fuel_level:int,lat:double,...
#    :  :- *(13) Project [timestamp#408, vehicle_id#409, speed#410, engine_temp#411, fuel_level#412, lat#413, lon#414, 11 AS dup_id#399, CASE WHEN (speed#410 < 40) THEN low WHEN (speed#410 < 80) THEN medium ELSE high END AS speed_category#920, (engine_temp#411 * speed#410) AS engine_stress#921]
#    :  :  +- *(13) Filter isnotnull(vehicle_id#409)
#    :  :     +- FileScan csv [timestamp#408,vehicle_id#409,speed#410,engine_temp#411,fuel_level#412,lat#413,lon#414] Batched: false, DataFilters: [isnotnull(vehicle_id#409)], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/opt/spark-data/telematics.csv], PartitionFilters: [], PushedFilters: [IsNotNull(vehicle_id)], ReadSchema: struct<timestamp:timestamp,vehicle_id:string,speed:int,engine_temp:int,fuel_level:int,lat:double,...
#    :  :- *(14) Project [timestamp#433, vehicle_id#434, speed#435, engine_temp#436, fuel_level#437, lat#438, lon#439, 12 AS dup_id#424, CASE WHEN (speed#435 < 40) THEN low WHEN (speed#435 < 80) THEN medium ELSE high END AS speed_category#922, (engine_temp#436 * speed#435) AS engine_stress#923]
#    :  :  +- *(14) Filter isnotnull(vehicle_id#434)
#    :  :     +- FileScan csv [timestamp#433,vehicle_id#434,speed#435,engine_temp#436,fuel_level#437,lat#438,lon#439] Batched: false, DataFilters: [isnotnull(vehicle_id#434)], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/opt/spark-data/telematics.csv], PartitionFilters: [], PushedFilters: [IsNotNull(vehicle_id)], ReadSchema: struct<timestamp:timestamp,vehicle_id:string,speed:int,engine_temp:int,fuel_level:int,lat:double,...
#    :  :- *(15) Project [timestamp#458, vehicle_id#459, speed#460, engine_temp#461, fuel_level#462, lat#463, lon#464, 13 AS dup_id#449, CASE WHEN (speed#460 < 40) THEN low WHEN (speed#460 < 80) THEN medium ELSE high END AS speed_category#924, (engine_temp#461 * speed#460) AS engine_stress#925]
#    :  :  +- *(15) Filter isnotnull(vehicle_id#459)
#    :  :     +- FileScan csv [timestamp#458,vehicle_id#459,speed#460,engine_temp#461,fuel_level#462,lat#463,lon#464] Batched: false, DataFilters: [isnotnull(vehicle_id#459)], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/opt/spark-data/telematics.csv], PartitionFilters: [], PushedFilters: [IsNotNull(vehicle_id)], ReadSchema: struct<timestamp:timestamp,vehicle_id:string,speed:int,engine_temp:int,fuel_level:int,lat:double,...
#    :  :- *(16) Project [timestamp#483, vehicle_id#484, speed#485, engine_temp#486, fuel_level#487, lat#488, lon#489, 14 AS dup_id#474, CASE WHEN (speed#485 < 40) THEN low WHEN (speed#485 < 80) THEN medium ELSE high END AS speed_category#926, (engine_temp#486 * speed#485) AS engine_stress#927]
#    :  :  +- *(16) Filter isnotnull(vehicle_id#484)
#    :  :     +- FileScan csv [timestamp#483,vehicle_id#484,speed#485,engine_temp#486,fuel_level#487,lat#488,lon#489] Batched: false, DataFilters: [isnotnull(vehicle_id#484)], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/opt/spark-data/telematics.csv], PartitionFilters: [], PushedFilters: [IsNotNull(vehicle_id)], ReadSchema: struct<timestamp:timestamp,vehicle_id:string,speed:int,engine_temp:int,fuel_level:int,lat:double,...
#    :  :- *(17) Project [timestamp#508, vehicle_id#509, speed#510, engine_temp#511, fuel_level#512, lat#513, lon#514, 15 AS dup_id#499, CASE WHEN (speed#510 < 40) THEN low WHEN (speed#510 < 80) THEN medium ELSE high END AS speed_category#928, (engine_temp#511 * speed#510) AS engine_stress#929]
#    :  :  +- *(17) Filter isnotnull(vehicle_id#509)
#    :  :     +- FileScan csv [timestamp#508,vehicle_id#509,speed#510,engine_temp#511,fuel_level#512,lat#513,lon#514] Batched: false, DataFilters: [isnotnull(vehicle_id#509)], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/opt/spark-data/telematics.csv], PartitionFilters: [], PushedFilters: [IsNotNull(vehicle_id)], ReadSchema: struct<timestamp:timestamp,vehicle_id:string,speed:int,engine_temp:int,fuel_level:int,lat:double,...
#    :  :- *(18) Project [timestamp#533, vehicle_id#534, speed#535, engine_temp#536, fuel_level#537, lat#538, lon#539, 16 AS dup_id#524, CASE WHEN (speed#535 < 40) THEN low WHEN (speed#535 < 80) THEN medium ELSE high END AS speed_category#930, (engine_temp#536 * speed#535) AS engine_stress#931]
#    :  :  +- *(18) Filter isnotnull(vehicle_id#534)
#    :  :     +- FileScan csv [timestamp#533,vehicle_id#534,speed#535,engine_temp#536,fuel_level#537,lat#538,lon#539] Batched: false, DataFilters: [isnotnull(vehicle_id#534)], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/opt/spark-data/telematics.csv], PartitionFilters: [], PushedFilters: [IsNotNull(vehicle_id)], ReadSchema: struct<timestamp:timestamp,vehicle_id:string,speed:int,engine_temp:int,fuel_level:int,lat:double,...
#    :  :- *(19) Project [timestamp#558, vehicle_id#559, speed#560, engine_temp#561, fuel_level#562, lat#563, lon#564, 17 AS dup_id#549, CASE WHEN (speed#560 < 40) THEN low WHEN (speed#560 < 80) THEN medium ELSE high END AS speed_category#932, (engine_temp#561 * speed#560) AS engine_stress#933]
#    :  :  +- *(19) Filter isnotnull(vehicle_id#559)
#    :  :     +- FileScan csv [timestamp#558,vehicle_id#559,speed#560,engine_temp#561,fuel_level#562,lat#563,lon#564] Batched: false, DataFilters: [isnotnull(vehicle_id#559)], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/opt/spark-data/telematics.csv], PartitionFilters: [], PushedFilters: [IsNotNull(vehicle_id)], ReadSchema: struct<timestamp:timestamp,vehicle_id:string,speed:int,engine_temp:int,fuel_level:int,lat:double,...
#    :  :- *(20) Project [timestamp#583, vehicle_id#584, speed#585, engine_temp#586, fuel_level#587, lat#588, lon#589, 18 AS dup_id#574, CASE WHEN (speed#585 < 40) THEN low WHEN (speed#585 < 80) THEN medium ELSE high END AS speed_category#934, (engine_temp#586 * speed#585) AS engine_stress#935]
#    :  :  +- *(20) Filter isnotnull(vehicle_id#584)
#    :  :     +- FileScan csv [timestamp#583,vehicle_id#584,speed#585,engine_temp#586,fuel_level#587,lat#588,lon#589] Batched: false, DataFilters: [isnotnull(vehicle_id#584)], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/opt/spark-data/telematics.csv], PartitionFilters: [], PushedFilters: [IsNotNull(vehicle_id)], ReadSchema: struct<timestamp:timestamp,vehicle_id:string,speed:int,engine_temp:int,fuel_level:int,lat:double,...
#    :  +- *(21) Project [timestamp#608, vehicle_id#609, speed#610, engine_temp#611, fuel_level#612, lat#613, lon#614, 19 AS dup_id#599, CASE WHEN (speed#610 < 40) THEN low WHEN (speed#610 < 80) THEN medium ELSE high END AS speed_category#936, (engine_temp#611 * speed#610) AS engine_stress#937]
#    :     +- *(21) Filter isnotnull(vehicle_id#609)
#    :        +- FileScan csv [timestamp#608,vehicle_id#609,speed#610,engine_temp#611,fuel_level#612,lat#613,lon#614] Batched: false, DataFilters: [isnotnull(vehicle_id#609)], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/opt/spark-data/telematics.csv], PartitionFilters: [], PushedFilters: [IsNotNull(vehicle_id)], ReadSchema: struct<timestamp:timestamp,vehicle_id:string,speed:int,engine_temp:int,fuel_level:int,lat:double,...
#    +- BroadcastExchange HashedRelationBroadcastMode(List(input[0, string, false]),false), [plan_id=900]
#       +- *(22) Filter isnotnull(vehicle_id#48)
#          +- FileScan csv [vehicle_id#48,model#49,plant#50,year#51] Batched: false, DataFilters: [isnotnull(vehicle_id#48)], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/opt/spark-data/vehicles.csv], PartitionFilters: [], PushedFilters: [IsNotNull(vehicle_id)], ReadSchema: struct<vehicle_id:string,model:string,plant:string,year:int>

# %%
import time

start = time.time()
df_tele.join(df_vehicle, "vehicle_id").count()
print("Shuffle Join Time:", time.time() - start)

start = time.time()
df_tele.join(broadcast(df_vehicle), "vehicle_id").count()
print("Broadcast Join Time:", time.time() - start)
# Out:
# Shuffle Join Time: 0.5715718269348145
# Broadcast Join Time: 0.587454080581665

# %% [markdown]
# ### Imputing disturbances/skewness in the dataset

# %%
df_big.groupBy("vehicle_id").count().show()
# Out:
# +----------+------+
# |vehicle_id| count|
# +----------+------+
# |        V3|181440|
# |        V4|181440|
# |        V5|181440|
# |        V2|181440|
# |        V1|181440|
# +----------+------+

# %%
from pyspark.sql.functions import when, rand

df_skewed = df_big.withColumn(
    "vehicle_id",
    when(rand() < 0.7, "V1").otherwise(df_big.vehicle_id)
)

# %%
df_skewed_part = df_skewed.repartition(5, "vehicle_id")

# %%
df_skewed_part.groupBy("vehicle_id").count().show()
# Out:
# +----------+------+
# |vehicle_id| count|
# +----------+------+
# |        V5| 54363|
# |        V4| 54240|
# |        V3| 54327|
# |        V2| 54361|
# |        V1|689909|
# +----------+------+

# %%
df_skewed_part.rdd.glom().map(len).collect()
# Out:
# [0, 54363, 108567, 54361, 689909]

# %%
spark.conf.get("spark.sql.adaptive.enabled")
# Out:
# 'false'

# %%
import time

start = time.time()
df_skewed_part.join(df_vehicle, "vehicle_id").count()
print("Shuffle Join Time:", time.time() - start)

start = time.time()
df_skewed_part.join(broadcast(df_vehicle), "vehicle_id").count()
print("Broadcast Join Time:", time.time() - start)
# Out:
# Shuffle Join Time: 0.7851302623748779
# Broadcast Join Time: 0.5465037822723389
